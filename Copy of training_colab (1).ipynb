# %% [markdown]
# # Classification of power spectra with BaCoN
#
# This notebook shows how to classify a dark matter power spectrum using the pre-trained BaCoN model. It can be used to classify any new spectrum. See the data description for the format required

# %% [markdown]
# ## Load the code
#
# Here we mount the drive and import BaCoN. If running on your machine, be sure to have tensorflow2 and tensorflow probability installed and jump directly to the imports.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive//MyDrive/BaCoN-II-errors
# Out:
# /content/drive/MyDrive/BaCoN-II-errors

# %%
import sys, os, platform
import tensorflow as tf

print("Python:", sys.version)
print("Executable:", sys.executable)
print("Platform:", platform.platform())
print("TF:", tf.__version__)

# Keras identity (Keras 3 vs legacy)
print("tf.keras:", tf.keras.__file__)

try:
    import keras
    print("standalone keras:", keras.__version__, keras.__file__)
except Exception as e:
    print("standalone keras import failed:", repr(e))

# TFP
try:
    import tensorflow_probability as tfp
    print("TFP:", tfp.__version__)
except Exception as e:
    print("TFP import failed:", repr(e))

# GPU visibility
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Executable: /usr/bin/python3
# Platform: Linux-6.6.113+-x86_64-with-glibc2.35
# TF: 2.19.0
# tf.keras: /usr/local/lib/python3.12/dist-packages/keras/_tf_keras/keras/__init__.py
# standalone keras: 3.13.2 /usr/local/lib/python3.12/dist-packages/keras/__init__.py
# TFP: 0.25.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !which python
# !python -c "import sys, tensorflow as tf; print(sys.version); print(sys.executable); print('TF', tf.__version__)"
# Out:
# /usr/local/bin/python
# 2026-03-19 10:52:45.317830: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773917565.349375    4986 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773917565.359864    4986 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773917565.382590    4986 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773917565.382618    4986 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773917565.382626    4986 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773917565.382632    4986 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# /usr/bin/python3
# TF 2.19.0

# %%
# !pip install -q "tf-keras==2.19.0"

# %%
import os;
import numpy as np
import subprocess
import argparse
from test import *
from utils import *
from models import *
from data_generator import *
from train import *
from importer import load_model_for_test, my_predict, predict_bayes_label, predict_mean_proba
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = 'serif'
plt.rcParams["mathtext.fontset"] = "cm"

# %% [markdown]
# ## Training a new network
# If you want to load a pre-trained network, like the default BaCoN-II network, skip ahead to the next sections.

# %%
# !sudo apt-get update -y && \
 sudo apt-get install -y python3.11 python3.11-venv && \
 python3.11 -m venv /content/py311 && \
 source /content/py311/bin/activate && \
 pip install -q --upgrade pip && \
 pip install -q lib5c && \
 lib5c -v

# %%
# %ls data/
# Out:
# Kaiser_5to4_test/       Nonlin_6to5/             Nonlin_someimprovement/
# Kaiser_5to4_train/      Nonlin_finalcheck/       Nonlin_someimprovement_test/
# Kaiser_6to5_test/       Nonlin_finalcheck_test/  Planck_fiducial_nonlin.txt
# Kaiser_6to5_wcdm_test/  Nonlin_fixed/            Planck_fiducial_reducedk.txt
# Kaiser_7to6_test/       Nonlin_fixedomegarc/     test6to5/
# Kaiser_7to6_train/      Nonlin_frrange_train/    Κaiser_6to5_train/
# Kaiser_MidVary_test/    Nonlin_ogparams/
# Kaiser_MidVary_train/   Nonlin_ogparams_test/

# %% [markdown]
# ### set parameters for training

# %%
# Training options:

# ------------------ change the training directory and model name here ------------------

# training data directory path - uncomment ONE of the following four lines
## (batch size, is a multiple of #models * noise realisations, e.g. 5 models, 10 noise --> must be multiple of 50)
DIR='data/Nonlin_6to5'; batch_size='150'; train_fname = '3000' # 100 examples per class, batch size for 5 models, 10 noise
#DIR='data/train_5_classes_1k'; batch_size='2500'; train_fname = 'train_1k' # 1000 examples per class, batch size for 5 models, 10 noise
#DIR='data/test_5_classes_1k'; batch_size='2500'; train_fname = 'test_1k' # 1000 examples per class, batch size for 5 models, 10 noise
#DIR='data/test_5_classes_100'; batch_size='500'; train_fname = 'test_100' # 100 examples per class, batch size for 5 models, 10 noise

# adapt the name of the model
fname = 'Nonlin_6to5'
fname = fname + '_' + train_fname

# training the network
GPU='True' # Use GPUs in training?
# which kind of model
bayesian='True' # Bayesian NN or traditional NN (weights single valued or distributions?)
n_epochs='50' # How many epochs to train for?


# ------------------ ignore all the other parameters for now ------------------

# Directories
mypath=None # Parent directory

# Edit this with base model directory
mdir='models/'

# normalisation file
norm_data_name = '/Planck_fiducial_nonlin.txt'

# scale cut and resolution
k_max='10.0' # which k-modes to include?
sample_pace='4'

# should the processed curves be saved in an extra file (False recommended, only efficient for n_epochs = 1)
save_processed_spectra='False'

# -------------------- noise model --------------------

# noise model - Cosmic variance and shot noise are Euclid-like
n_noisy_samples='10' # How many noise examples to train on?
add_noise='True'# Add noise?
add_shot='False'# Add shot noise term? -- default should be False (we're using dark matter spectra)
add_sys='False'# Add systematic error term?
add_cosvar='False'# Add cosmic variance term?

# path to folder with theory error curves
curves_folder = 'data/curve_files_sys/theory_error/filters_earliest_onset'; sigma_curves_default = '0.05'
# change rescale distribution of theory error curves, uniform recommended
rescale_curves = 'uniform' # or gaussian or None

# sys error curves - relative scale of curve-amplitude
sigma_curves='0.15'

# -------------------- noise model --------------------
noise_model = 'linear_kaiser'  # 'default' or 'linear_kaiser'
kaiser_bias = 1.0
kaiser_ng = 0.00128 # adjust for data redshift
kaiser_veff = 0.283
kaiser_delta_k = 0.01

# -------------------- additional training settings --------------------


# Type of model
model_name='custom' # Custom or dummy - dummy has presets as given in models.py

# fine-tune = only 'LCDM' and 'non-LCDM'
fine_tune='False' # Model trained to distinguish between 'LCDM' and 'non-LCDM' classes or between all clases. i.e. binary or multi-classifier

#Test mode?
test_mode='False' # Network trained on 1 batch of minimal size or not?
seed='1312' # Initial seed for test mode batch
# Saving or restoring training
restore='False' # Restore training from a checkpoint?
save_ckpt='True' # Save checkpoints?


val_size='0.15' # Validation set % of data set

add_FT_dense='False' #if True, adds an additional dense layer before the final 2D one

patience='50' # terminate training after 'patience' epochs if no decrease in loss function
lr='0.01' # learning rate
decay='0.95' #decay rate: If None : Adam(lr),




# -------------------- BNN parameters -----------------

# Example image details
im_depth='500' # Number in z direction (e.g. 500 wave modes for P(k) examples)
im_width='1' # Number in y direction (1 is a 2D image : P(k,mu))
im_channels='2'  # Number in x direction (e.g. 4 redshifts for P(k,z))
swap_axes='True' # Do we swap depth and width axes? True if we have 1D image in 4 channels
sort_labels='True' # Sorts labels in ascending/alphabetical order

# for linear kaiser, only two z bins are necessary as p4 carries little to no added
# information and the fifth column stores the growth parameter used in error calculation
z1='0' # which z-bins to include? Assumes each channel is a new z bin.
z2='1' # which z-bins to include? Assumes each channel is a new z bin.
#z3='2' # which z-bins to include? Assumes each channel is a new z bin.
# z4='3' # which z-bins to include? Assumes each channel is a new z bin.

# Number of layers and kernel sizes
k1='10'
k2='5'
k3='2'
 # The dimensionality of the output space (i.e. the number of filters in the convolution)
f1='8'
f2='16'
f3='32'
 # Stride of each layer's kernel
s1='2'
s2='2'
s3='1'
# Pooling layer sizes
p1='2'
p2='2'
p3='0'
# Strides in Pooling layer
sp1='2'
sp2='1'
sp3='0'

n_dense='1' # Number of dense layers

# labels of different cosmologies
#c0_label = 'lcdm'
#c1_label = 'fR dgp wcdm'

log_path = mdir+fname+'_log'
if fine_tune == "True":
    log_path_original= log_path
    log_path += '_FT'
    log_path_original += '.txt'
else:
    log_path_original=''

log_path += '.txt'

# %% [markdown]
# ### run the training
# this may take a while to run, also expect some (harmless) error messages in the output

# %%
import os

# Path to your training dataset
data_dir = "data/Nonlin_6to5"

# List all model folders
model_folders = [f for f in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, f))]

# Count files in each folder
for model in model_folders:
    folder_path = os.path.join(data_dir, model)
    n_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"{model}: {n_files} samples")
# Out:
# fR: 1000 samples
# LCDM: 1000 samples
# nDGP: 1000 samples

# %%
import os, sys, subprocess

env = os.environ.copy()
env["TF_USE_LEGACY_KERAS"] = "1"   # critical for TFP Flipout + TF 2.19/Keras 3

proc = subprocess.Popen(
    [sys.executable, "train.py",
     "--test_mode", str(test_mode),
     "--seed", str(seed),
     "--bayesian", str(bayesian),
     "--model_name", str(model_name),
     "--fine_tune", str(fine_tune),
     "--log_path", str(log_path_original),
     "--restore", str(restore),
     "--models_dir", str(mdir),
     "--fname", str(fname),
     "--DIR", str(DIR),
     "--norm_data_name", str(norm_data_name),
     "--curves_folder", str(curves_folder),
     "--c_0", "LCDM",
     "--c_1", "nDGP", "fR",
     "--save_ckpt", str(save_ckpt),
     "--im_depth", str(im_depth), "--im_width", str(im_width), "--im_channels", str(im_channels),
     "--swap_axes", str(swap_axes),
     "--sort_labels", str(sort_labels),
     "--add_noise", str(add_noise), "--add_shot", str(add_shot), "--add_sys", str(add_sys), "--add_cosvar", str(add_cosvar),
     "--sigma_curves", str(sigma_curves),
     "--sigma_curves_default", str(sigma_curves_default),
     "--save_processed_spectra", str(save_processed_spectra),
     "--sample_pace", str(sample_pace),
     "--n_noisy_samples", str(n_noisy_samples),
     "--rescale_curves", str(rescale_curves),
     #----- linear parameters
     "--noise_model", str(noise_model),
     "--kaiser_bias", str(kaiser_bias),
     "--kaiser_ng", str(kaiser_ng),
     "--kaiser_veff", str(kaiser_veff),
     "--kaiser_delta_k", str(kaiser_delta_k),
     #------
     "--val_size", str(val_size),
     "--z_bins", str(z1), str(z2),
     #str(z3),
     #str(z4),
     "--filters", str(f1), str(f2), str(f3),
     "--kernel_sizes", str(k1), str(k2), str(k3),
     "--strides", str(s1), str(s2), str(s3),
     "--pool_sizes", str(p1), str(p2), str(p3),
     "--strides_pooling", str(sp1), str(sp2), str(sp3),
     "--k_max", str(k_max),
     "--n_dense", str(n_dense),
     "--add_FT_dense", str(add_FT_dense),
     "--n_epochs", str(n_epochs), "--patience", str(patience), "--batch_size", str(batch_size), "--lr", str(lr),
     "--decay", str(decay),
     "--GPU", str(GPU)],
    env=env,
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True,          # makes stdout/stderr strings (simplifies decode)
    bufsize=1
)

with open(log_path, "w") as log_file:
    while proc.poll() is None:
        line = proc.stderr.readline()
        if line:
            print("err:", line.rstrip())
            log_file.write(line)
        line = proc.stdout.readline()
        if line:
            print("out:", line.rstrip())
            log_file.write(line)

# 🔻 After the process exits, drain any remaining output
    remaining_out, remaining_err = proc.communicate()

    if remaining_err:
        for line in remaining_err.splitlines():
            print("err:", line)
            log_file.write(line + "\n")

    if remaining_out:
        for line in remaining_out.splitlines():
            print("out:", line)
            log_file.write(line + "\n")

    print("Process return code:", proc.returncode)
# Out:
# err: 2026-03-25 20:44:15.029430: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# out: Creating directory models/Nonlin_6to5_3000
# err: WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# out: Logger creating log file: models/Nonlin_6to5_3000/Nonlin_6to5_3000_log.txt
# err: E0000 00:00:1774471455.054128    4711 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# out:
# err: E0000 00:00:1774471455.062972    4711 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# out:  -------- Parameters:
# err: W0000 00:00:1774471455.082892    4711 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# out: bayesian True
# err: W0000 00:00:1774471455.082918    4711 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# out: test_mode False
# err: W0000 00:00:1774471455.082920    4711 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# out: n_test_idx 2
# err: W0000 00:00:1774471455.082922    4711 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# out: seed 1312
# err: 2026-03-25 20:44:15.089199: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# out: fine_tune False
# err: To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# out: one_vs_all False
# err: /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
# out: c_0 ['LCDM']
# err:   loc = add_variable_fn(
# out: c_1 ['fR', 'nDGP']
# err: 2026-03-25 20:44:28.808422: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# out: dataset_balanced True
# err: I0000 00:00:1774471468.811216    4711 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# out: include_last False
# err: /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
# out: log_path
# err:   untransformed_scale = add_variable_fn(
# out: restore False
# err: /usr/local/lib/python3.12/dist-packages/tf_keras/src/initializers/initializers.py:121: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
# out: fname Nonlin_6to5_3000
# err:   warnings.warn(
# out: model_name custom
# err: I0000 00:00:1774471470.941755    4711 gpu_device.cc:2019] Created device /device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# out: my_path None
# err: I0000 00:00:1774471481.841434    4794 cuda_dnn.cc:529] Loaded cuDNN version 91002
# out: DIR data/Nonlin_6to5
# err: WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# out: TEST_DIR data/test_data/
# err: I0000 00:00:1774471483.162086    4794 service.cc:152] XLA service 0x7a0a53212e10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# out: models_dir models/
# err: I0000 00:00:1774471483.162113    4794 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# out: save_ckpt True
# err: 2026-03-25 20:44:43.193038: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# out: out_path_overwrite False
# err: I0000 00:00:1774471483.443250    4794 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# out: curves_folder data/curve_files_sys/theory_error/filters_earliest_onset
# out: save_processed_spectra False
# out: im_depth 500
# out: im_width 1
# out: im_channels 2
# out: swap_axes True
# out: sort_labels True
# out: norm_data_name /Planck_fiducial_nonlin.txt
# out: normalization stdcosmo
# out: sample_pace 4
# out: k_max 10.0
# out: i_max None
# out: add_noise True
# out: n_noisy_samples 10
# out: add_shot False
# out: add_sys False
# out: add_cosvar False
# out: noise_model linear_kaiser
# out: kaiser_bias 1.0
# out: kaiser_ng 0.00128
# out: kaiser_veff 0.283
# out: kaiser_delta_k 0.01
# out: sigma_sys None
# out: sys_scaled None
# out: sys_factor None
# out: sys_max None
# out: sigma_curves 0.15
# out: sigma_curves_default 0.05
# out: rescale_curves uniform
# out: z_bins [0, 1]
# out: n_dense 1
# out: filters [8, 16, 32]
# out: kernel_sizes [10, 5, 2]
# out: strides [2, 2, 1]
# out: pool_sizes [2, 2, 0]
# out: strides_pooling [2, 1, 0]
# out: add_FT_dense False
# out: trainable False
# out: unfreeze False
# out: lr 0.01
# out: drop 0.5
# out: n_epochs 50
# out: val_size 0.15
# out: test_size 0.0
# out: batch_size 150
# out: patience 50
# out: GPU True
# out: decay 0.95
# out: BatchNorm True
# out:
# out: ------------ CREATING DATA GENERATORS ------------
# out: labels : ['LCDM', 'fR', 'nDGP']
# out: Labels encoding:
# out: {'LCDM': 0, 'fR': 1, 'nDGP': 2}
# out: n_labels : 3
# out: LCDM - 1000 training examples
# out: fR - 1000 training examples
# out: nDGP - 1000 training examples
# out:
# out: N. of data files: 1000
# out: get_all_indexes labels dict: {'LCDM': 0, 'fR': 1, 'nDGP': 2}
# out: create_generators n_labels: 3
# out: create_generators n_labels_eff: 3
# out: create_generators len_c1: 1
# out: Check for no duplicates in test: (0=ok):
# out: 0.0
# out: Check for no duplicates in val: (0=ok):
# out: 0
# out: N of files in training set: 850
# out: N of files in validation set: 150
# out: N of files in test set: 0
# out: Check - total: 1000
# out: --create_generators, train indexes
# out: batch_size: 150
# out: - Cut sample
# out: bs: 150
# out: N_labels: 3
# out: N_noise: 10
# out: len_c1: 1
# out: Train index length: 850
# out: --create_generators, validation indexes
# out: - Cut sample
# out: bs: 150
# out: N_labels: 3
# out: N_noise: 10
# out: len_c1: 1
# out: Val index length: 150
# out: len(train_index_1), batch_size, n_labels_eff, n_noisy_samples = 850, 150, 3, 10
# out:
# out: --DataGenerator Train
# out: Data Generator Initialization
# out: Using z bins [0, 1]
# out: Normalisation file is /Planck_fiducial_nonlin.txt
# out: Specified k_max is 10.0
# out: Corresponding i_max is 124
# out: Closest k to k_max is 0.19643016074493946
# out: New data dim: (124, 1)
# out: Final i_max used is 124
# out: one_vs_all: False
# out: dataset_balanced: False
# out: base_case_dataset: True
# out: N. classes: 3
# out: N. n_classes in output: 3
# out: LABELS: ['LCDM', 'fR', 'nDGP']
# out: list_IDs length: 850
# out: n_indexes (n of file IDs read for each batch): 5
# out: batch size: 150
# out: n_batches : 170
# out: For each batch we read 5 file IDs
# out: For each file ID we have 3 labels
# out: For each ID, label we have 10 realizations of noise
# out: In total, for each batch we have 150 training examples
# out: Input batch size: 150
# out: N of batches to cover all file IDs: 170
# out:
# out: --DataGenerator Validation
# out: Data Generator Initialization
# out: Using z bins [0, 1]
# out: Normalisation file is /Planck_fiducial_nonlin.txt
# out: Specified k_max is 10.0
# out: Corresponding i_max is 124
# out: Closest k to k_max is 0.19643016074493946
# out: New data dim: (124, 1)
# out: Final i_max used is 124
# out: one_vs_all: False
# out: dataset_balanced: False
# out: base_case_dataset: True
# out: N. classes: 3
# out: N. n_classes in output: 3
# out: LABELS: ['LCDM', 'fR', 'nDGP']
# out: list_IDs length: 150
# out: n_indexes (n of file IDs read for each batch): 5
# out: batch size: 150
# out: n_batches : 30
# out: For each batch we read 5 file IDs
# out: For each file ID we have 3 labels
# out: For each ID, label we have 10 realizations of noise
# out: In total, for each batch we have 150 training examples
# out: Input batch size: 150
# out: N of batches to cover all file IDs: 30
# out: ------------ DONE ------------
# out:
# out: ------------ BUILDING MODEL ------------
# out: Input shape (124, 2)
# out: using 1D layers and 2 channels
# out: Expected output dimension of layer conv1d_flipout: 58.0
# out: Expected output dimension of layer max_pooling1d: 29.0
# out: Expected output dimension of layer conv1d_flipout_1: 13.0
# out: Expected output dimension of layer max_pooling1d_1: 12.0
# out: Expected output dimension of layer conv1d_flipout_2: 11.0
# out: Model: "model"
# out: _________________________________________________________________
# out:  Layer (type)                Output Shape              Param #
# out: =================================================================
# out:  input_1 (InputLayer)        [(None, 124, 2)]          0
# out:
# out:  conv1d_flipout (Conv1DFlip  (None, 58, 8)             328
# out:  out)
# out:
# out:  max_pooling1d (MaxPooling1  (None, 29, 8)             0
# out:  D)
# out:
# out:  batch_normalization (Batch  (None, 29, 8)             32
# out:  Normalization)
# out:
# out:  conv1d_flipout_1 (Conv1DFl  (None, 13, 16)            1296
# out:  ipout)
# out:
# out:  max_pooling1d_1 (MaxPoolin  (None, 12, 16)            0
# out:  g1D)
# out:
# out:  batch_normalization_1 (Bat  (None, 12, 16)            64
# out:  chNormalization)
# out:
# out:  conv1d_flipout_2 (Conv1DFl  (None, 11, 32)            2080
# out:  ipout)
# out:
# out:  batch_normalization_2 (Bat  (None, 11, 32)            128
# out:  chNormalization)
# out:
# out:  global_average_pooling1d (  (None, 32)                0
# out:  GlobalAveragePooling1D)
# out:
# out:  dense_flipout (DenseFlipou  (None, 32)                2080
# out:  t)
# out:
# out:  batch_normalization_3 (Bat  (None, 32)                128
# out:  chNormalization)
# out:
# out:  dense_flipout_1 (DenseFlip  (None, 3)                 195
# out:  out)
# out:
# out: =================================================================
# out: Total params: 6331 (24.73 KB)
# out: Trainable params: 6155 (24.04 KB)
# out: Non-trainable params: 176 (704.00 Byte)
# out: _________________________________________________________________
# out: None
# out: Found GPU at: /device:GPU:0
# out: ------------ TRAINING ------------
# out:
# out: Features shape: (150, 124, 2)
# out: Labels shape: (150, 3)
# out: Initializing checkpoint from scratch.
# out: Epoch 0
# out: Validation loss decreased. Saved checkpoint for step 1: models/Nonlin_6to5_3000/tf_ckpts/ckpt-1
# out: Time:  827.58s, ---- Loss: 0.8569, Acc.: 0.6207, Val. Loss: 2.3635, Val. Acc.: 0.5716
# out:
# out: Epoch 1
# out: Validation loss decreased. Saved checkpoint for step 2: models/Nonlin_6to5_3000/tf_ckpts/ckpt-2
# out: Time:  17.69s, ---- Loss: 0.7486, Acc.: 0.6690, Val. Loss: 1.8876, Val. Acc.: 0.6718
# out:
# out: Epoch 2
# out: Validation loss decreased. Saved checkpoint for step 3: models/Nonlin_6to5_3000/tf_ckpts/ckpt-3
# out: Time:  17.59s, ---- Loss: 0.7492, Acc.: 0.6810, Val. Loss: 1.7384, Val. Acc.: 0.6731
# out:
# out: Epoch 3
# out: Loss did not decrease. Count = 1
# out: Time:  17.23s, ---- Loss: 0.6794, Acc.: 0.7066, Val. Loss: 2.7741, Val. Acc.: 0.5302
# out:
# out: Epoch 4
# out: Loss did not decrease. Count = 2
# out: Time:  17.48s, ---- Loss: 0.7254, Acc.: 0.7418, Val. Loss: 2.0860, Val. Acc.: 0.5347
# out:
# out: Epoch 5
# out: Validation loss decreased. Saved checkpoint for step 6: models/Nonlin_6to5_3000/tf_ckpts/ckpt-4
# out: Time:  18.66s, ---- Loss: 0.6982, Acc.: 0.7809, Val. Loss: 1.4172, Val. Acc.: 0.7362
# out:
# out: Epoch 6
# out: Validation loss decreased. Saved checkpoint for step 7: models/Nonlin_6to5_3000/tf_ckpts/ckpt-5
# out: Time:  17.80s, ---- Loss: 0.3947, Acc.: 0.8125, Val. Loss: 1.2992, Val. Acc.: 0.7902
# out:
# out: Epoch 7
# out: Validation loss decreased. Saved checkpoint for step 8: models/Nonlin_6to5_3000/tf_ckpts/ckpt-6
# out: Time:  17.73s, ---- Loss: 0.3369, Acc.: 0.8609, Val. Loss: 1.0873, Val. Acc.: 0.8698
# out:
# out: Epoch 8
# out: Validation loss decreased. Saved checkpoint for step 9: models/Nonlin_6to5_3000/tf_ckpts/ckpt-7
# out: Time:  17.29s, ---- Loss: 0.2653, Acc.: 0.8935, Val. Loss: 1.0258, Val. Acc.: 0.8949
# out:
# out: Epoch 9
# out: Validation loss decreased. Saved checkpoint for step 10: models/Nonlin_6to5_3000/tf_ckpts/ckpt-8
# out: Time:  17.45s, ---- Loss: 0.2283, Acc.: 0.9133, Val. Loss: 0.9641, Val. Acc.: 0.9093
# out:
# out: Epoch 10
# out: Validation loss decreased. Saved checkpoint for step 11: models/Nonlin_6to5_3000/tf_ckpts/ckpt-9
# out: Time:  17.93s, ---- Loss: 0.2297, Acc.: 0.9247, Val. Loss: 0.9388, Val. Acc.: 0.9116
# out:
# out: Epoch 11
# out: Loss did not decrease. Count = 1
# out: Time:  17.17s, ---- Loss: 0.2395, Acc.: 0.9378, Val. Loss: 1.0416, Val. Acc.: 0.8818
# out:
# out: Epoch 12
# out: Loss did not decrease. Count = 2
# out: Time:  17.03s, ---- Loss: 0.1914, Acc.: 0.9444, Val. Loss: 0.9437, Val. Acc.: 0.9018
# out:
# out: Epoch 13
# out: Validation loss decreased. Saved checkpoint for step 14: models/Nonlin_6to5_3000/tf_ckpts/ckpt-10
# out: Time:  17.16s, ---- Loss: 0.1663, Acc.: 0.9452, Val. Loss: 0.8293, Val. Acc.: 0.9384
# out:
# out: Epoch 14
# out: Validation loss decreased. Saved checkpoint for step 15: models/Nonlin_6to5_3000/tf_ckpts/ckpt-11
# out: Time:  17.58s, ---- Loss: 0.1906, Acc.: 0.9551, Val. Loss: 0.8203, Val. Acc.: 0.9356
# out:
# out: Epoch 15
# out: Validation loss decreased. Saved checkpoint for step 16: models/Nonlin_6to5_3000/tf_ckpts/ckpt-12
# out: Time:  18.07s, ---- Loss: 0.1495, Acc.: 0.9603, Val. Loss: 0.7665, Val. Acc.: 0.9584
# out:
# out: Epoch 16
# out: Loss did not decrease. Count = 1
# out: Time:  17.66s, ---- Loss: 0.1566, Acc.: 0.9621, Val. Loss: 0.8582, Val. Acc.: 0.9296
# out:
# out: Epoch 17
# out: Validation loss decreased. Saved checkpoint for step 18: models/Nonlin_6to5_3000/tf_ckpts/ckpt-13
# out: Time:  17.57s, ---- Loss: 0.1418, Acc.: 0.9587, Val. Loss: 0.7285, Val. Acc.: 0.9642
# out:
# out: Epoch 18
# out: Loss did not decrease. Count = 1
# out: Time:  17.09s, ---- Loss: 0.1426, Acc.: 0.9638, Val. Loss: 0.7392, Val. Acc.: 0.9584
# out:
# out: Epoch 19
# out: Validation loss decreased. Saved checkpoint for step 20: models/Nonlin_6to5_3000/tf_ckpts/ckpt-14
# out: Time:  17.15s, ---- Loss: 0.1518, Acc.: 0.9667, Val. Loss: 0.6786, Val. Acc.: 0.9767
# out:
# out: Epoch 20
# out: Loss did not decrease. Count = 1
# out: Time:  17.46s, ---- Loss: 0.1590, Acc.: 0.9687, Val. Loss: 0.7925, Val. Acc.: 0.9422
# out:
# out: Epoch 21
# out: Validation loss decreased. Saved checkpoint for step 22: models/Nonlin_6to5_3000/tf_ckpts/ckpt-15
# out: Time:  17.95s, ---- Loss: 0.1411, Acc.: 0.9685, Val. Loss: 0.6546, Val. Acc.: 0.9780
# out:
# out: Epoch 22
# out: Validation loss decreased. Saved checkpoint for step 23: models/Nonlin_6to5_3000/tf_ckpts/ckpt-16
# out: Time:  17.52s, ---- Loss: 0.1416, Acc.: 0.9711, Val. Loss: 0.6525, Val. Acc.: 0.9760
# out:
# out: Epoch 23
# out: Validation loss decreased. Saved checkpoint for step 24: models/Nonlin_6to5_3000/tf_ckpts/ckpt-17
# out: Time:  17.44s, ---- Loss: 0.1339, Acc.: 0.9672, Val. Loss: 0.6419, Val. Acc.: 0.9771
# out:
# out: Epoch 24
# out: Loss did not decrease. Count = 1
# out: Time:  17.14s, ---- Loss: 0.1713, Acc.: 0.9737, Val. Loss: 0.6672, Val. Acc.: 0.9649
# out:
# out: Epoch 25
# out: Loss did not decrease. Count = 2
# out: Time:  17.53s, ---- Loss: 0.1664, Acc.: 0.9716, Val. Loss: 0.6838, Val. Acc.: 0.9551
# out:
# out: Epoch 26
# out: Validation loss decreased. Saved checkpoint for step 27: models/Nonlin_6to5_3000/tf_ckpts/ckpt-18
# out: Time:  18.27s, ---- Loss: 0.1225, Acc.: 0.9740, Val. Loss: 0.6264, Val. Acc.: 0.9769
# out:
# out: Epoch 27
# out: Loss did not decrease. Count = 1
# out: Time:  17.63s, ---- Loss: 0.1243, Acc.: 0.9762, Val. Loss: 0.6350, Val. Acc.: 0.9704
# out:
# out: Epoch 28
# out: Validation loss decreased. Saved checkpoint for step 29: models/Nonlin_6to5_3000/tf_ckpts/ckpt-19
# out: Time:  17.67s, ---- Loss: 0.1391, Acc.: 0.9764, Val. Loss: 0.6199, Val. Acc.: 0.9758
# out:
# out: Epoch 29
# out: Validation loss decreased. Saved checkpoint for step 30: models/Nonlin_6to5_3000/tf_ckpts/ckpt-20
# out: Time:  17.62s, ---- Loss: 0.1225, Acc.: 0.9756, Val. Loss: 0.6078, Val. Acc.: 0.9767
# out:
# out: Epoch 30
# out: Validation loss decreased. Saved checkpoint for step 31: models/Nonlin_6to5_3000/tf_ckpts/ckpt-21
# out: Time:  17.97s, ---- Loss: 0.1116, Acc.: 0.9765, Val. Loss: 0.6060, Val. Acc.: 0.9760
# out:
# out: Epoch 31
# out: Validation loss decreased. Saved checkpoint for step 32: models/Nonlin_6to5_3000/tf_ckpts/ckpt-22
# out: Time:  18.18s, ---- Loss: 0.1064, Acc.: 0.9765, Val. Loss: 0.6033, Val. Acc.: 0.9769
# out:
# out: Epoch 32
# out: Validation loss decreased. Saved checkpoint for step 33: models/Nonlin_6to5_3000/tf_ckpts/ckpt-23
# out: Time:  17.85s, ---- Loss: 0.1140, Acc.: 0.9791, Val. Loss: 0.5833, Val. Acc.: 0.9829
# out:
# out: Epoch 33
# out: Loss did not decrease. Count = 1
# out: Time:  17.65s, ---- Loss: 0.1085, Acc.: 0.9787, Val. Loss: 0.5860, Val. Acc.: 0.9820
# out:
# out: Epoch 34
# out: Validation loss decreased. Saved checkpoint for step 35: models/Nonlin_6to5_3000/tf_ckpts/ckpt-24
# out: Time:  17.78s, ---- Loss: 0.1018, Acc.: 0.9790, Val. Loss: 0.5728, Val. Acc.: 0.9842
# out:
# out: Epoch 35
# out: Validation loss decreased. Saved checkpoint for step 36: models/Nonlin_6to5_3000/tf_ckpts/ckpt-25
# out: Time:  18.58s, ---- Loss: 0.1012, Acc.: 0.9796, Val. Loss: 0.5662, Val. Acc.: 0.9873
# out:
# out: Epoch 36
# out: Validation loss decreased. Saved checkpoint for step 37: models/Nonlin_6to5_3000/tf_ckpts/ckpt-26
# out: Time:  18.23s, ---- Loss: 0.1044, Acc.: 0.9805, Val. Loss: 0.5630, Val. Acc.: 0.9847
# out:
# out: Epoch 37
# out: Loss did not decrease. Count = 1
# out: Time:  17.33s, ---- Loss: 0.1002, Acc.: 0.9797, Val. Loss: 0.5805, Val. Acc.: 0.9747
# out:
# out: Epoch 38
# out: Validation loss decreased. Saved checkpoint for step 39: models/Nonlin_6to5_3000/tf_ckpts/ckpt-27
# out: Time:  17.45s, ---- Loss: 0.1024, Acc.: 0.9808, Val. Loss: 0.5568, Val. Acc.: 0.9840
# out:
# out: Epoch 39
# out: Loss did not decrease. Count = 1
# out: Time:  17.52s, ---- Loss: 0.1060, Acc.: 0.9808, Val. Loss: 0.5614, Val. Acc.: 0.9796
# out:
# out: Epoch 40
# out: Validation loss decreased. Saved checkpoint for step 41: models/Nonlin_6to5_3000/tf_ckpts/ckpt-28
# out: Time:  18.34s, ---- Loss: 0.1039, Acc.: 0.9816, Val. Loss: 0.5536, Val. Acc.: 0.9824
# out:
# out: Epoch 41
# out: Loss did not decrease. Count = 1
# out: Time:  17.51s, ---- Loss: 0.0989, Acc.: 0.9809, Val. Loss: 0.5577, Val. Acc.: 0.9816
# out:
# out: Epoch 42
# out: Loss did not decrease. Count = 2
# out: Time:  17.58s, ---- Loss: 0.1134, Acc.: 0.9813, Val. Loss: 0.5559, Val. Acc.: 0.9798
# out:
# out: Epoch 43
# out: Validation loss decreased. Saved checkpoint for step 44: models/Nonlin_6to5_3000/tf_ckpts/ckpt-29
# out: Time:  17.59s, ---- Loss: 0.0979, Acc.: 0.9818, Val. Loss: 0.5429, Val. Acc.: 0.9853
# out:
# out: Epoch 44
# out: Loss did not decrease. Count = 1
# out: Time:  16.87s, ---- Loss: 0.1007, Acc.: 0.9824, Val. Loss: 0.5507, Val. Acc.: 0.9791
# out:
# out: Epoch 45
# out: Loss did not decrease. Count = 2
# out: Time:  17.34s, ---- Loss: 0.0965, Acc.: 0.9823, Val. Loss: 0.5443, Val. Acc.: 0.9838
# out:
# out: Epoch 46
# out: Loss did not decrease. Count = 3
# out: Time:  17.61s, ---- Loss: 0.1025, Acc.: 0.9835, Val. Loss: 0.5466, Val. Acc.: 0.9822
# out:
# out: Epoch 47
# out: Validation loss decreased. Saved checkpoint for step 48: models/Nonlin_6to5_3000/tf_ckpts/ckpt-30
# out: Time:  17.20s, ---- Loss: 0.0976, Acc.: 0.9831, Val. Loss: 0.5371, Val. Acc.: 0.9827
# out:
# out: Epoch 48
# out: Validation loss decreased. Saved checkpoint for step 49: models/Nonlin_6to5_3000/tf_ckpts/ckpt-31
# out: Time:  17.58s, ---- Loss: 0.0987, Acc.: 0.9834, Val. Loss: 0.5315, Val. Acc.: 0.9842
# out:
# out: Epoch 49
# out: Loss did not decrease. Count = 1
# out: Time:  16.88s, ---- Loss: 0.1027, Acc.: 0.9824, Val. Loss: 0.5361, Val. Acc.: 0.9822
# out:
# out: Saving at models/Nonlin_6to5_3000/hist.png
# out: Done in 1701.44s
# Process return code: 0

# %%
ls models/
# Out:
# Kaiser_5to4_3000/              Kaiser_7to6_nowcdm_3000/
# Kaiser_5to4_3000_log.txt       Kaiser_7to6_nowcdm_3000_log.txt
# Kaiser_6to5_3000/              Non_linear_finalog_3000/
# Kaiser_6to5_3000_log.txt       Non_linear_finalog_3000_log.txt
# Kaiser_6to5_wCDM_3000/         nonlin_frrange_3000/
# Kaiser_6to5_wCDM_3000_log.txt  nonlin_frrange_3000_log.txt
# Kaiser_7to6_3000/              nonlin_og_3000/
# Kaiser_7to6_3000_log.txt       nonlin_og_3000_log.txt

# %% [markdown]
# ## Run the test of the model to produce confusion matrix
# - insert the path+name of the log file of the model
# - change the test directory
# - change the custom name that will be used for the confusion matrix
#
# The pdf file with the confusion matrix is saved in the model folder.

# %%
ls models
# Out:
# Kaiser_5to4_3000/                   Nonlin_6to5_3000/
# Kaiser_5to4_3000_log.txt            Nonlin_6to5_3000_log.txt
# Kaiser_6to5_3000/                   Non_linear_finalog_3000/
# Kaiser_6to5_3000_log.txt            Non_linear_finalog_3000_log.txt
# Kaiser_6to5_wCDM_3000/              Nonlin_finalcheck_3000/
# Kaiser_6to5_wCDM_3000_log.txt       Nonlin_finalcheck_3000_log.txt
# Kaiser_7to6_3000/                   nonlin_frrange_3000/
# Kaiser_7to6_3000_log.txt            nonlin_frrange_3000_log.txt
# Kaiser_7to6_nowcdm_3000/            Nonlin_improvementonbounds_3000/
# Kaiser_7to6_nowcdm_3000_log.txt     Nonlin_improvementonbounds_3000_log.txt
# Kaiser_ogparams_noise_3000/         nonlin_og_3000/
# Kaiser_ogparams_noise_3000_log.txt  nonlin_og_3000_log.txt

# %%
# !TF_USE_LEGACY_KERAS=1 python test.py --log_path='models/Nonlin_6to5_3000/Nonlin_6to5_3000_log.txt' \
  --TEST_DIR='data/test6to5' --cm_name_custom='test-colab' --batch_size=60
# Out:
# 2026-03-25 21:16:53.640363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774473413.669416   14264 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774473413.678781   14264 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774473413.701893   14264 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774473413.701931   14264 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774473413.701936   14264 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774473413.701943   14264 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-25 21:16:53.708161: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Reading log from models/Nonlin_6to5_3000/Nonlin_6to5_3000_log.txt
#
#  -------- Loaded parameters:
# bayesian True
# test_mode False
# n_test_idx 2
# seed 1312
# fine_tune False
# one_vs_all False
# c_0 ['LCDM']
# c_1 ['fR', 'nDGP']
# dataset_balanced True
# include_last False
# log_path
# restore False
# fname Nonlin_6to5_3000
# model_name custom
# my_path None
# DIR data/Nonlin_6to5
# TEST_DIR data/test_data/
# models_dir models/
# save_ckpt True
# out_path_overwrite False
# curves_folder data/curve_files_sys/theory_error/filters_earliest_onset
# save_processed_spectra False
# im_depth 500
# im_width 1
# im_channels 2
# swap_axes True
# sort_labels True
# norm_data_name /Planck_fiducial_nonlin.txt
# normalization stdcosmo
# sample_pace 4
# k_max 10.0
# i_max None
# add_noise True
# n_noisy_samples 10
# add_shot False
# add_sys False
# add_cosvar False
# noise_model linear_kaiser
# kaiser_bias 1.0
# kaiser_ng 0.00128
# kaiser_veff 0.283
# kaiser_delta_k 0.01
# sigma_sys None
# sys_scaled None
# sys_factor None
# sys_max None
# sigma_curves 0.15
# sigma_curves_default 0.05
# rescale_curves uniform
# z_bins [0, 1]
# n_dense 1
# filters [8, 16, 32]
# kernel_sizes [10, 5, 2]
# strides [2, 2, 1]
# pool_sizes [2, 2, 0]
# strides_pooling [2, 1, 0]
# add_FT_dense False
# trainable False
# unfreeze False
# lr 0.01
# drop 0.5
# n_epochs 50
# val_size 0.15
# test_size 0.0
# batch_size 150
# patience 50
# GPU True
# decay 0.95
# BatchNorm True
# group_lab_dict {'fR': 'non_lcdm', 'nDGP': 'non_lcdm', 'LCDM': 'LCDM'}
# FLAGS.one_vs_all : False
# TEST_NORM_FILE: FLAGS.norm_data_name from log_path  /Planck_fiducial_nonlin.txt
# Saving cm at test-colab
# Setting save_indexes to False
# Using data in the directory data/test6to5
# Using batch_size 60
# TEST_NORM_FILE: FLAGS.norm_data_name after args written to FLAGS /Planck_fiducial_nonlin.txt
# -------------------- out_path with FLAGS_fname models/Nonlin_6to5_3000
# Logger creating log file: models/Nonlin_6to5_3000/cm_test-colab_log.txt
#
#  -------- Parameters:
# bayesian True
# test_mode False
# n_test_idx 2
# seed 1312
# fine_tune False
# one_vs_all False
# c_0 ['LCDM']
# c_1 ['fR', 'nDGP']
# dataset_balanced True
# include_last False
# log_path
# restore False
# fname Nonlin_6to5_3000
# model_name custom
# my_path None
# DIR data/Nonlin_6to5
# TEST_DIR data/test6to5
# models_dir models/
# save_ckpt True
# out_path_overwrite False
# curves_folder data/curve_files_sys/theory_error/filters_earliest_onset
# save_processed_spectra False
# im_depth 500
# im_width 1
# im_channels 2
# swap_axes True
# sort_labels True
# norm_data_name /Planck_fiducial_nonlin.txt
# normalization stdcosmo
# sample_pace 4
# k_max 10.0
# i_max None
# add_noise True
# n_noisy_samples 10
# add_shot False
# add_sys False
# add_cosvar False
# noise_model linear_kaiser
# kaiser_bias 1.0
# kaiser_ng 0.00128
# kaiser_veff 0.283
# kaiser_delta_k 0.01
# sigma_sys None
# sys_scaled None
# sys_factor None
# sys_max None
# sigma_curves 0.15
# sigma_curves_default 0.05
# rescale_curves uniform
# z_bins [0, 1]
# n_dense 1
# filters [8, 16, 32]
# kernel_sizes [10, 5, 2]
# strides [2, 2, 1]
# pool_sizes [2, 2, 0]
# strides_pooling [2, 1, 0]
# add_FT_dense False
# trainable False
# unfreeze False
# lr 0.01
# drop 0.5
# n_epochs 50
# val_size 0.15
# test_size 0.0
# batch_size 60
# patience 50
# GPU True
# decay 0.95
# BatchNorm True
# group_lab_dict {'fR': 'non_lcdm', 'nDGP': 'non_lcdm', 'LCDM': 'LCDM'}
# save_indexes False
# ------------ CREATING DATA GENERATORS ------------
#
# labels : ['LCDM', 'fR', 'nDGP']
# Labels encoding:
# {'LCDM': 0, 'fR': 1, 'nDGP': 2}
# n_labels : 3
# LCDM - 200 training examples
# fR - 200 training examples
# nDGP - 200 training examples
#
# N. of data files: 200
# get_all_indexes labels dict: {'LCDM': 0, 'fR': 1, 'nDGP': 2}
# create_generators n_labels_eff: 3
# create_generators len_c1: 1
# --Train
# batch_size: 60
# - Cut sample
# bs: 60
# N_labels: 3
# N_noise: 10
# len_c1: 1
# Indexes length: 200
# n_keep: 200
# Sampling
# New length: 200
# N batches: 100.0
#  len_C1: 1
# N indexes: 2.0
# Ok.
# N. of test files used: 200
# Data Generator Initialization
# Using z bins [0, 1]
# Normalisation file is /Planck_fiducial_nonlin.txt
# Specified k_max is 10.0
# Corresponding i_max is 124
# Closest k to k_max is 0.19643016074493946
# New data dim: (124, 1)
# Final i_max used is 124
# one_vs_all: False
# dataset_balanced: False
# base_case_dataset: True
# N. classes: 3
# N. n_classes in output: 3
# LABELS: ['LCDM', 'fR', 'nDGP']
# list_IDs length: 200
# n_indexes (n of file IDs read for each batch): 2
# batch size: 60
# n_batches : 100
# For each batch we read 2 file IDs
# For each file ID we have 3 labels
# For each ID, label we have 10 realizations of noise
# In total, for each batch we have 60 training examples
# Input batch size: 60
# N of batches to cover all file IDs: 100
# ------------ DONE ------------
#
# Input shape (124, 2)
# ------------ BUILDING MODEL ------------
#
# Model n_classes : 3
# Features shape: (60, 124, 2)
# Labels shape: (60, 3)
# using 1D layers and 2 channels
# Expected output dimension of layer conv1d_flipout: 58.0
# /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# 2026-03-25 21:17:05.113839: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1774473425.115350   14264 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# /usr/local/lib/python3.12/dist-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/initializers/initializers.py:121: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Expected output dimension of layer max_pooling1d: 29.0
# Expected output dimension of layer conv1d_flipout_1: 13.0
# Expected output dimension of layer max_pooling1d_1: 12.0
# Expected output dimension of layer conv1d_flipout_2: 11.0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 124, 2)]          0
#
#  conv1d_flipout (Conv1DFlip  (None, 58, 8)             328
#  out)
#
#  max_pooling1d (MaxPooling1  (None, 29, 8)             0
#  D)
#
#  batch_normalization (Batch  (None, 29, 8)             32
#  Normalization)
#
#  conv1d_flipout_1 (Conv1DFl  (None, 13, 16)            1296
#  ipout)
#
#  max_pooling1d_1 (MaxPoolin  (None, 12, 16)            0
#  g1D)
#
#  batch_normalization_1 (Bat  (None, 12, 16)            64
#  chNormalization)
#
#  conv1d_flipout_2 (Conv1DFl  (None, 11, 32)            2080
#  ipout)
#
#  batch_normalization_2 (Bat  (None, 11, 32)            128
#  chNormalization)
#
#  global_average_pooling1d (  (None, 32)                0
#  GlobalAveragePooling1D)
#
#  dense_flipout (DenseFlipou  (None, 32)                2080
#  t)
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_flipout_1 (DenseFlip  (None, 3)                 195
#  out)
#
# =================================================================
# Total params: 6331 (24.73 KB)
# Trainable params: 6155 (24.04 KB)
# Non-trainable params: 176 (704.00 Byte)
# _________________________________________________________________
# None
# Computing loss for randomly initialized model...
# I0000 00:00:1774473426.078314   14264 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Loss before loading weights/ 2.3442345
#
# ------------ RESTORING CHECKPOINTS ------------
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Looking for ckpt in models/Nonlin_6to5_3000/tf_ckpts/
# Restoring checkpoint from models/Nonlin_6to5_3000/tf_ckpts/ckpt-31
# Loss after loading weights/ 0.359644
#
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).step
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._iterations
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._current_learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.31
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.32
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.33
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.34
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.35
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.36
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.37
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.38
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.39
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.40
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.41
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.42
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.43
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.44
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.45
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.46
# Threshold probability for classification: 0.5
# Accuracy on 0 batch using median of sampled probabilities: 1.0 %
# Accuracy on 0 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 1 batch using median of sampled probabilities: 1.0 %
# Accuracy on 1 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 2 batch using median of sampled probabilities: 1.0 %
# Accuracy on 2 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 3 batch using median of sampled probabilities: 1.0 %
# Accuracy on 3 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 4 batch using median of sampled probabilities: 1.0 %
# Accuracy on 4 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 5 batch using median of sampled probabilities: 1.0 %
# Accuracy on 5 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 6 batch using median of sampled probabilities: 1.0 %
# Accuracy on 6 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 7 batch using median of sampled probabilities: 1.0 %
# Accuracy on 7 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 8 batch using median of sampled probabilities: 1.0 %
# Accuracy on 8 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 9 batch using median of sampled probabilities: 1.0 %
# Accuracy on 9 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 10 batch using median of sampled probabilities: 0.9166667 %
# Accuracy on 10 batch using median of sampled probabilities, not considering unclassified examples: 0.9166667 %
# Accuracy on 11 batch using median of sampled probabilities: 1.0 %
# Accuracy on 11 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 12 batch using median of sampled probabilities: 1.0 %
# Accuracy on 12 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 13 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 13 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 14 batch using median of sampled probabilities: 1.0 %
# Accuracy on 14 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 15 batch using median of sampled probabilities: 1.0 %
# Accuracy on 15 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 16 batch using median of sampled probabilities: 1.0 %
# Accuracy on 16 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 17 batch using median of sampled probabilities: 1.0 %
# Accuracy on 17 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 18 batch using median of sampled probabilities: 1.0 %
# Accuracy on 18 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 19 batch using median of sampled probabilities: 1.0 %
# Accuracy on 19 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 20 batch using median of sampled probabilities: 1.0 %
# Accuracy on 20 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 21 batch using median of sampled probabilities: 1.0 %
# Accuracy on 21 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 22 batch using median of sampled probabilities: 1.0 %
# Accuracy on 22 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 23 batch using median of sampled probabilities: 1.0 %
# Accuracy on 23 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 24 batch using median of sampled probabilities: 0.85 %
# Accuracy on 24 batch using median of sampled probabilities, not considering unclassified examples: 0.86440676 %
# Accuracy on 25 batch using median of sampled probabilities: 1.0 %
# Accuracy on 25 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 26 batch using median of sampled probabilities: 1.0 %
# Accuracy on 26 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 27 batch using median of sampled probabilities: 1.0 %
# Accuracy on 27 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 28 batch using median of sampled probabilities: 1.0 %
# Accuracy on 28 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 29 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 29 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 30 batch using median of sampled probabilities: 1.0 %
# Accuracy on 30 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 31 batch using median of sampled probabilities: 1.0 %
# Accuracy on 31 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 32 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 32 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 33 batch using median of sampled probabilities: 1.0 %
# Accuracy on 33 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 34 batch using median of sampled probabilities: 1.0 %
# Accuracy on 34 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 35 batch using median of sampled probabilities: 1.0 %
# Accuracy on 35 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 36 batch using median of sampled probabilities: 1.0 %
# Accuracy on 36 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 37 batch using median of sampled probabilities: 1.0 %
# Accuracy on 37 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 38 batch using median of sampled probabilities: 1.0 %
# Accuracy on 38 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 39 batch using median of sampled probabilities: 1.0 %
# Accuracy on 39 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 40 batch using median of sampled probabilities: 1.0 %
# Accuracy on 40 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 41 batch using median of sampled probabilities: 1.0 %
# Accuracy on 41 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 42 batch using median of sampled probabilities: 1.0 %
# Accuracy on 42 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 43 batch using median of sampled probabilities: 1.0 %
# Accuracy on 43 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 44 batch using median of sampled probabilities: 1.0 %
# Accuracy on 44 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 45 batch using median of sampled probabilities: 1.0 %
# Accuracy on 45 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 46 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 46 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 47 batch using median of sampled probabilities: 1.0 %
# Accuracy on 47 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 48 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 48 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 49 batch using median of sampled probabilities: 1.0 %
# Accuracy on 49 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 50 batch using median of sampled probabilities: 1.0 %
# Accuracy on 50 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 51 batch using median of sampled probabilities: 1.0 %
# Accuracy on 51 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 52 batch using median of sampled probabilities: 1.0 %
# Accuracy on 52 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 53 batch using median of sampled probabilities: 1.0 %
# Accuracy on 53 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 54 batch using median of sampled probabilities: 1.0 %
# Accuracy on 54 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 55 batch using median of sampled probabilities: 1.0 %
# Accuracy on 55 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 56 batch using median of sampled probabilities: 0.6666667 %
# Accuracy on 56 batch using median of sampled probabilities, not considering unclassified examples: 0.6666667 %
# Accuracy on 57 batch using median of sampled probabilities: 1.0 %
# Accuracy on 57 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 58 batch using median of sampled probabilities: 1.0 %
# Accuracy on 58 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 59 batch using median of sampled probabilities: 1.0 %
# Accuracy on 59 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 60 batch using median of sampled probabilities: 1.0 %
# Accuracy on 60 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 61 batch using median of sampled probabilities: 1.0 %
# Accuracy on 61 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 62 batch using median of sampled probabilities: 1.0 %
# Accuracy on 62 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 63 batch using median of sampled probabilities: 1.0 %
# Accuracy on 63 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 64 batch using median of sampled probabilities: 1.0 %
# Accuracy on 64 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 65 batch using median of sampled probabilities: 1.0 %
# Accuracy on 65 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 66 batch using median of sampled probabilities: 1.0 %
# Accuracy on 66 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 67 batch using median of sampled probabilities: 1.0 %
# Accuracy on 67 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 68 batch using median of sampled probabilities: 1.0 %
# Accuracy on 68 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 69 batch using median of sampled probabilities: 1.0 %
# Accuracy on 69 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 70 batch using median of sampled probabilities: 1.0 %
# Accuracy on 70 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 71 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 71 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 72 batch using median of sampled probabilities: 1.0 %
# Accuracy on 72 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 73 batch using median of sampled probabilities: 1.0 %
# Accuracy on 73 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 74 batch using median of sampled probabilities: 1.0 %
# Accuracy on 74 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 75 batch using median of sampled probabilities: 0.8333333 %
# Accuracy on 75 batch using median of sampled probabilities, not considering unclassified examples: 0.8333333 %
# Accuracy on 76 batch using median of sampled probabilities: 1.0 %
# Accuracy on 76 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 77 batch using median of sampled probabilities: 1.0 %
# Accuracy on 77 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 78 batch using median of sampled probabilities: 1.0 %
# Accuracy on 78 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 79 batch using median of sampled probabilities: 1.0 %
# Accuracy on 79 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 80 batch using median of sampled probabilities: 1.0 %
# Accuracy on 80 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 81 batch using median of sampled probabilities: 1.0 %
# Accuracy on 81 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 82 batch using median of sampled probabilities: 1.0 %
# Accuracy on 82 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 83 batch using median of sampled probabilities: 1.0 %
# Accuracy on 83 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 84 batch using median of sampled probabilities: 1.0 %
# Accuracy on 84 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 85 batch using median of sampled probabilities: 1.0 %
# Accuracy on 85 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 86 batch using median of sampled probabilities: 1.0 %
# Accuracy on 86 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 87 batch using median of sampled probabilities: 1.0 %
# Accuracy on 87 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 88 batch using median of sampled probabilities: 1.0 %
# Accuracy on 88 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 89 batch using median of sampled probabilities: 1.0 %
# Accuracy on 89 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 90 batch using median of sampled probabilities: 1.0 %
# Accuracy on 90 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 91 batch using median of sampled probabilities: 1.0 %
# Accuracy on 91 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 92 batch using median of sampled probabilities: 1.0 %
# Accuracy on 92 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 93 batch using median of sampled probabilities: 1.0 %
# Accuracy on 93 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 94 batch using median of sampled probabilities: 1.0 %
# Accuracy on 94 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 95 batch using median of sampled probabilities: 1.0 %
# Accuracy on 95 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 96 batch using median of sampled probabilities: 1.0 %
# Accuracy on 96 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 97 batch using median of sampled probabilities: 1.0 %
# Accuracy on 97 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 98 batch using median of sampled probabilities: 1.0 %
# Accuracy on 98 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# Accuracy on 99 batch using median of sampled probabilities: 1.0 %
# Accuracy on 99 batch using median of sampled probabilities, not considering unclassified examples: 1.0 %
# -- Accuracy on test set using median of sampled probabilities: 0.98266673 %
#
# -- Accuracy on test set using median of sampled probabilities, not considering unclassified examples: 0.9828108 %
#
# Adding Not classified label
# Saved confusion matrix at models/Nonlin_6to5_3000/cm_test-colab_frozen_weights.pdf
# Saved confusion matrix values at models/Nonlin_6to5_3000/cm_test-colab_frozen_weights_values.txt
# No individual results file found at models/Nonlin_6to5_3000/individual_results_test-colab.csv. Skipping parameter plots.
# No individual results file found at models/Nonlin_6to5_3000/individual_results_test-colab.csv. Skipping sensitivity curve.

# %% [markdown]
# ## Run the model on single test spectra

# %% [markdown]
# ### Function to load trained models and data

# %%
def read_pre_trained_flags(args_dict):
  '''
  Read model options from logfile and return them in the form of FLAGS (the corresponding class is in utils)
  '''
  args = DummyFlags(args_dict)
  FLAGS = get_flags(args.log_path)
  if args.models_dir is not None:
        print('Reading model from the directory %s' %args.models_dir)
        FLAGS.models_dir = args.models_dir
  return FLAGS


def get_pre_trained_model(fname, n_classes, input_shape):
  '''
  returns pre-trained model.
  Input:  - fname: string, folder where the trained model is stored
          - n_classes: integer, number of output classes of the model
          - input_shape:  tuple, input dimensions of the model.
                          For pre-trained model in the paper use (100, 4)

  '''

  log_path = os.path.join('models', fname, fname+'_log.txt' )
  models_dir = os.path.join('models', fname)

  args_dict= {'log_path':log_path, 'models_dir': models_dir, }
  FLAGS=read_pre_trained_flags(args_dict)

  print('Input shape %s' %str(input_shape))


  model_loaded =  load_model_for_test(FLAGS, input_shape, n_classes=n_classes,
                                        generator=None, new_fname='')


  return model_loaded



def load_X(fname, sample_pace, i_max, norm_data,
           add_noise=True, normalise=True, use_sample_pace=False, include_k=True,
           noise_model='linear_kaiser',
           bias=1.0, ng=0.00128, veff=0.283, delta_k=0.01, P_lin=None):
  '''
  Generates one power spectrum X ready for classification.
  Returns k, P0, P2, P4 as separate arrays, each noised and normalised individually.

  Options:  fname: path to data
            sample_pace: read one point every sample_pace
            i_max: Index corresponding to the max k used
            norm_data: normalisation spectrum (Planck), shape (nk, 3) for [P0, P2, P4]
            add_noise: whether to add noise or not
            normalise: normalise each multipole by its own Planck column
            use_sample_pace: whether to apply sample_pace
            include_k: return k as well
            bias: galaxy bias
            ng: galaxy number density
            veff: effective survey volume in (Gpc/h)³
  '''

  data = np.loadtxt(fname)
  print('loaded data shape: %s' % str(data.shape))

  k    = data[:, 0].copy()
  P0   = data[:, 1].copy()
  P2   = data[:, 2].copy()


  if use_sample_pace:
      k, P0, P2 = k[::sample_pace], P0[::sample_pace], P2[::sample_pace]

  k, P0, P2 = k[:i_max], P0[:i_max], P2[:i_max]
  print('shape after k max: %s' % str(k.shape))

  if add_noise:
      # Stack into (nk, 3) for generate_noise
      X_stack = np.stack([P0, P2], axis=1)

  # Handle P_lin slicing to match k
      P_lin_use = P_lin
      if P_lin_use is not None:
          if use_sample_pace:
              P_lin_use = P_lin_use[::sample_pace]
          P_lin_use = P_lin_use[:i_max]

      sigma = generate_noise(k, X_stack,
                             add_sys=True, add_shot=False, sigma_sys=5,
                             noise_model=noise_model,
                             bias=bias, ng=ng, veff=veff, delta_k=delta_k, P_lin=P_lin_use)
      noise = np.random.normal(loc=0, scale=sigma)
      P0 = P0 + noise[:, 0]
      P2 = P2 + noise[:, 1]


  if normalise:
      planck = norm_data
      print('planck data shape: %s' % str(planck.shape))
      # Normalise each multipole by its own Planck column
      P0 = P0 / planck[:i_max, 0] - 1
      P2 = P2 / planck[:i_max, 1] - 1

  if include_k:
      return k, P0, P2
  else:
      return P0, P2

# %% [markdown]
# ### Functions for getting confidence

# %%
def sample_from_data(model,  my_Xs_norm,  my_min=np.zeros(5), my_max=np.ones(5),
                     n_samples=50000, num_monte_carlo=100, th_prob=0.5,
                     verbose=True):
  '''
  Given some normalized features my_Xs_norm and the model, compute mu and Sigma as in the paper eq. 2.8-2.9
  and return samples from the probability distribuion eq. 2.10
  '''
  Al_error, Ep_error, mean = get_mu_Sigma(model, my_Xs_norm , num_monte_carlo=num_monte_carlo, th_prob=th_prob, verbose=verbose)
  Sigma = (Al_error+ Ep_error).numpy()
  MM = mean.numpy()
  if verbose:
    print('Sigma')
    print(np.round(Sigma, 3))
  samples, z_samples = sample_probas(Sigma, MM, my_min=my_min,my_max=my_max, n_samples=n_samples, verbose=verbose)

  return samples, z_samples, Sigma, MM



def get_mu_Sigma(model, my_Xs_norm, num_monte_carlo=100, th_prob=0.5, verbose=True):
  ''''
  Given some normalized features my_Xs_norm and the model, compute mu and Sigma as in the paper eq. 2.8-2.9
  '''
  if verbose:
    print('Computing mu and sigma...')
  sampled_probas, _, _ = my_predict(tf.expand_dims(my_Xs_norm, axis=0), model, num_monte_carlo=num_monte_carlo, th_prob=th_prob)
  mean = tf.reduce_mean(sampled_probas[:,0,:], axis=0)
  _, Al_error, Ep_error = get_err_variances(sampled_probas[:,0,:])
  return Al_error, Ep_error, mean


def sample_probas(Sigma, MM, my_min=np.zeros(5), my_max=np.ones(5), n_samples=50000, verbose=True):
  '''
  Given mu and Sigma as in the paper eq. 2.8-2.9, computes B, U as described in appendix B of the paper.
  Then calls function to sample the prob. distribution (eq. 2.10)
  '''
  if verbose:
    print('Sample probas call')
  evals, evecs = np.linalg.eig(Sigma)
  B = evecs
  U = B.T @ Sigma @  B
  if verbose:
    print('U')
    print(np.round(U, 3))
  n_dims=U.shape[0]-1
  n_dims=U.shape[0]-1
  ind_min = np.argmin(np.diag(U))
  if verbose:
    print('Index of min eigenvalue is: %s' %ind_min)
    print('Min eigenvalue is: %s' %np.min(np.diag(U)))
  UU = np.array([np.sqrt(U[i,i])  for i in range(U.shape[0]) if i!=ind_min ] )
  if verbose:
    print('U has %s elements ' %str(UU.shape[0]))
  samples, z_samples = get_samples(UU, B, MM, my_min=my_min, my_max=my_max, ind_min=ind_min, n_dims=n_dims, n_samples=n_samples, verbose=verbose)
  return samples, z_samples


def get_samples(UU, B, MM, my_min=np.zeros(5), my_max=np.ones(5), ind_min=-1, n_dims=4, n_samples=50000, verbose=True):
  '''
  samples eq. 2.10 as described in appendix B
  '''
  if verbose:
    print('Sampling...')
  samples = np.zeros((0, n_dims+1))
  z_samples = np.zeros((0, n_dims))
  while samples.shape[0] < n_samples:
    s = np.random.multivariate_normal( np.zeros(n_dims), np.diag(UU**2), size=(n_samples,))
    accepted = s[(np.min(X_val_batch(s, B, MM, null_ind=ind_min)-my_min, axis=1) >= 0) & (np.max(X_val_batch(s, B, MM, null_ind=ind_min) - my_max, axis=1) <= 0)]
    samples = np.concatenate((samples, X_val_batch(accepted, B, MM, null_ind=ind_min)), axis=0)
    z_samples = np.concatenate((z_samples, accepted), axis=0)
  samples = samples[:n_samples, :]
  z_samples = z_samples[:n_samples, :]
  if verbose:
    print('Done.')
  return samples, z_samples



def X_val_batch(Z, B, MM, null_ind):
  return np.array([ X_val(Z[i], B, MM, null_ind=null_ind,) for i in range(Z.shape[0])])

def Z(X, B, MM):
  '''  X must be 5-d '''
  return B.T @ (X-MM)

def X_val(Z, B, MM, null_ind=-1, verbose=False):
  '''  Z must be 4-d , MM must be 5-d '''
  if verbose:
    print(Z)
  Z = np.insert(Z, null_ind, 0)
  if verbose:
    print(Z)
  return B @ Z+ MM


def get_err_variances(prob_k, AlEp_split=True):
  '''
  Computes aleatoric and epistemic uncertainty from MC samples from the net. weights
  '''
  num_samples = prob_k.shape[0]
  prob_mean = tf.reduce_mean(prob_k, axis=0)

  diag_probs = tf.stack([np.diag(prob_k[i,:]) for i in range(num_samples)], axis=0)  # Diagonal matrix whose diagonal elements are the output of the network for the ith sample
  outer_products_Al = tf.stack([tf.tensordot(prob_k[i,:], prob_k[i,:], axes =0) for i in range(num_samples)], axis=0) # Outer self-product of the predictive vectors for the ith sample used in computing Al uncertainty
  outer_products_Ep = tf.stack([tf.tensordot(prob_k[i,:] - prob_mean, prob_k[i,:] - prob_mean, axes =0) for i in range(num_samples)], axis=0) # Outer self-product between the difference of the predictive vector for ith sampl and average prediction

  Al_error = tf.reduce_mean(diag_probs - outer_products_Al, axis=0) # Average over all the samples to compute aleotoric uncertainty
  Ep_error = tf.reduce_mean(outer_products_Ep, axis=0) # Average over all the samples to compute epistemic uncertainty

  tot_error = Al_error + Ep_error # Combine to compute total uncertainty
  confidences = tf.linalg.diag_part(tot_error).numpy()

  if AlEp_split:
    return confidences, Al_error, Ep_error
  else:
    return confidences



def get_P_from_samples(samples, th_prob=0.5 ):
  '''
  Given samples from eq. 2.10, computes the probabilities as in eq. 2.11
  '''
  Ntot = samples.shape[0] #-unclassified
  n_dims  = samples.shape[-1]
  all_preds = np.array([predict_bayes_label(sample, th_prob=th_prob) for sample in samples])
  unclassified=all_preds[all_preds==99].shape[0]

  n_in_class = np.array([all_preds[all_preds==k].shape[0] for k in range(n_dims)])

  #print('Ntot: %s  ' %Ntot)
  p_uncl=unclassified/Ntot
  #print('%s unclassified examples ' %unclassified)
  #print('P(unclassified)=%s ' %p_uncl)
  pp=n_in_class/Ntot
  #print(pp)
  #print(p_uncl)

  return np.append(pp, p_uncl)


def get_all_probas(X, model_loaded,
                   n_classes=5,
                   num_monte_carlo=100,
                   th_prob=0.5,
                   n_samples=10000,
                   verbose=True):
    '''
    Given features X, predicts the labels with MC samples from the net,
    computes mu and sigma, samples from the prob distribution
    and computes P.
    Returns result in the form of a dictionary
    '''

    # Gaussian approx
    samples, z_samples, Sigma, MM = sample_from_data(model_loaded,
                                                 my_Xs_norm=X,
                                                 my_min=np.zeros(n_classes), my_max=np.ones(n_classes),
                                                 n_samples=n_samples,
                                                 num_monte_carlo=num_monte_carlo,
                                                 th_prob=th_prob, verbose=verbose)

    P = get_P_from_samples(samples, th_prob=th_prob)
    if verbose:
      print('P: %s ' %str(P))
      print('P sum to %s' %P.sum())
    if verbose:
      print('mu  sum to %s' %MM.sum())


    # Result
    res = {'samples':samples, 'P':P, 'z_samples': z_samples, 'Sigma': Sigma, 'MM': MM,}
    return res


def plot_hist_1D(samples, MM, th_prob=0.5,
                  P=None, inv_labels_dict=None,):
  '''
  Plots histogram of gauss samples for each class
  '''

  n_dims = samples.shape[-1]-1
  fig, axs = plt.subplots(1, n_dims+1, sharey=True, sharex=False,figsize=(25,5))

  t_str=''
  for k in range(n_dims+1):

    axs[k].hist(samples.T[k], bins=15, color = "lightgray",lw=0, density=True, label='Gauss samples')
    axs[k].text(0.1, 0.9, '$\mu = $' + '$'+ str(MM[k])+'$', fontsize = 16 , transform=axs[k].transAxes);
    if P is  not None:
      axs[k].text(0.1, 0.8, '$ P = $' + '$'+ str(P[k])+'$', fontsize = 16 , transform=axs[k].transAxes);
      if k==0:
        t_str+= 'P unclassified: %s \n' %str(np.round(P[-1], 2) )
    axs[k].set_xlim(0,1)
    axs[k].set_ylim(0,10)

    if inv_labels_dict is not None:
      axs[k].set_title(inv_labels_dict[k])


    axs[k].legend(loc='lower right')

  axs[0].set_ylabel('P')
  fig.suptitle(t_str)

  plt.show()
# Out:
# <>:189: SyntaxWarning: invalid escape sequence '\m'
# <>:189: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_294/1369533956.py:189: SyntaxWarning: invalid escape sequence '\m'
#   axs[k].text(0.1, 0.9, '$\mu = $' + '$'+ str(MM[k])+'$', fontsize = 16 , transform=axs[k].transAxes);

# %% [markdown]
# ### Load the pretrained model
#
# Here we load the pre trained models

# %%
# Encoding of the labels for the two networks. Can be found in the log file of the training.
# Here it is easier to define it by hand.

inv_labels_dict_5={0:'dgp', 1:'fR', 2:'lcdm', 3:'n-wcdm', 4:'rand'}
inv_labels_dict_2={0:'lcdm', 1:'non-LCDM'}

# %% [markdown]
# Load in your model (path to the weight .txt) - here we load in the pre-trained Bacon model

# %%
model_5 = get_pre_trained_model('EE2_train20k_baseline', 5, (100, 4), )
# Out:
#  -------- Loaded parameters:
# bayesian True
# test_mode False
# n_test_idx 2
# seed 1312
# fine_tune False
# one_vs_all False
# c_0 ['lcdm']
# c_1 ['dgp', 'fR', 'rand', 'wcdm']
# dataset_balanced False
# include_last False
# log_path
# restore False
# fname EE2_train20k_baseline
# model_name custom
# my_path None
# DIR data/B2_20k/ee2/ee2_obstd_0p016/nu_wb/train
# TEST_DIR data/test_data/
# models_dir models/
# save_ckpt True
# out_path_overwrite False
# curves_folder data/curve_files_sys/theory_error/filters_earliest_onset
# save_processed_spectra False
# im_depth 500
# im_width 1
# im_channels 4
# swap_axes True
# sort_labels True
# norm_data_name /planck_ee2.txt
# normalization stdcosmo
# sample_pace 4
# k_max 2.5
# i_max None
# add_noise True
# n_noisy_samples 10
# add_shot False
# add_sys True
# add_cosvar True
# sigma_sys None
# sys_scaled None
# sys_factor None
# sys_max None
# sigma_curves 0.05
# sigma_curves_default 0.05
# rescale_curves uniform
# z_bins [0, 1, 2, 3]
# n_dense 1
# filters [8, 16, 32]
# kernel_sizes [10, 5, 2]
# strides [2, 2, 1]
# pool_sizes [2, 2, 0]
# strides_pooling [2, 1, 0]
# add_FT_dense False
# trainable False
# unfreeze False
# lr 0.01
# drop 0.5
# n_epochs 50
# val_size 0.15
# test_size 0.0
# batch_size 12500
# patience 50
# GPU False
# decay 0.95
# BatchNorm True
# group_lab_dict {'dgp': 'non_lcdm', 'fR': 'non_lcdm', 'rand': 'non_lcdm', 'wcdm': 'non_lcdm', 'lcdm': 'lcdm'}
# FLAGS.one_vs_all : False
# Reading model from the directory models/EE2_train20k_baseline
# Input shape (100, 4)
# ------------ BUILDING MODEL ------------
#
# Model n_classes : 5
# using 1D layers and 4 channels
# Expected output dimension of layer conv1d_flipout_9: 46.0
# Expected output dimension of layer max_pooling1d_6: 23.0
# Expected output dimension of layer conv1d_flipout_10: 10.0
# Expected output dimension of layer max_pooling1d_7: 9.0
# Expected output dimension of layer conv1d_flipout_11: 8.0
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 100, 4)]          0
#
#  conv1d_flipout_9 (Conv1DFl  (None, 46, 8)             648
#  ipout)
#
#  max_pooling1d_6 (MaxPoolin  (None, 23, 8)             0
#  g1D)
#
#  batch_normalization_12 (Ba  (None, 23, 8)             32
#  tchNormalization)
#
#  conv1d_flipout_10 (Conv1DF  (None, 10, 16)            1296
#  lipout)
#
#  max_pooling1d_7 (MaxPoolin  (None, 9, 16)             0
#  g1D)
#
#  batch_normalization_13 (Ba  (None, 9, 16)             64
#  tchNormalization)
#
#  conv1d_flipout_11 (Conv1DF  (None, 8, 32)             2080
#  lipout)
#
#  batch_normalization_14 (Ba  (None, 8, 32)             128
#  tchNormalization)
#
#  global_average_pooling1d_3  (None, 32)                0
#   (GlobalAveragePooling1D)
#
#  dense_flipout_6 (DenseFlip  (None, 32)                2080
#  out)
#
#  batch_normalization_15 (Ba  (None, 32)                128
#  tchNormalization)
#
#  dense_flipout_7 (DenseFlip  (None, 5)                 325
#  out)
#
# =================================================================
# Total params: 6781 (26.49 KB)
# Trainable params: 6605 (25.80 KB)
# Non-trainable params: 176 (704.00 Byte)
# _________________________________________________________________
# None
# ------------ RESTORING CHECKPOINT ------------
#
# Looking for ckpt in models/EE2_train20k_baseline/tf_ckpts/
# Restoring checkpoint from models/EE2_train20k_baseline/tf_ckpts/ckpt-28
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).step
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay

# %% [markdown]
# ### Load in the spectrum we wish to test
#
# Template for loading spectra. Suppose you saved the spectrum in
# 'data/example_spectra/my_ex.txt' . The spectrum is in 4 redshift bins and with 100 points between 0.01 - 2.5 in k . We normalize by the reference planck spectrum and add gaussian noise, then pass it to the five-label network.

# %% [markdown]
# Load normalization data first

# %%
sample_pace = 2
i_max = 500

# Pass raw planck, let load_X slice it
planck = np.loadtxt('data/Nonlin_ogparams/Planck_fiducial_nonlin.txt')[:, 1:][::sample_pace][:i_max]
P_lin = np.loadtxt('data/Nonlin_ogparams/Planck_fiducial_nonlin.txt')[:,3]

# %%
k, P0, P2 = load_X('data/Nonlin_someimprovement/Planck_fiducial_nonlin.txt',
                 sample_pace=sample_pace, i_max=500,
                 norm_data=planck,
                 add_noise=True, normalise=True, use_sample_pace=True, P_lin=P_lin)

k, P0_clean, P2_clean = load_X('data/Nonlin_someimprovement/Planck_fiducial_nonlin.txt',
                 sample_pace=sample_pace, i_max=500,
                 norm_data=planck,
                 add_noise=False, normalise=True, use_sample_pace=True, P_lin=P_lin)

kL, P0L, P2L = load_X('data/Nonlin_someimprovement/LCDM/5.txt',
                 sample_pace=sample_pace, i_max=500,
                 norm_data=planck,
                 add_noise=True, normalise=True, use_sample_pace=True, P_lin=P_lin)

kL, P0_cleanL, P2_cleanL = load_X('data/Nonlin_someimprovement/LCDM/5.txt',
                 sample_pace=sample_pace, i_max=500,
                 norm_data=planck,
                 add_noise=False, normalise=True, use_sample_pace=True, P_lin=P_lin)

kn, P0n, P2n = load_X('data/Nonlin_someimprovement/nDGP/5.txt',
                 sample_pace=sample_pace, i_max=500,
                 norm_data=planck,
                 add_noise=True, normalise=True, use_sample_pace=True, P_lin=P_lin)

kn, P0_cleann, P2_cleann = load_X('data/Nonlin_someimprovement/nDGP/5.txt',
                 sample_pace=sample_pace, i_max=500,
                 norm_data=planck,
                 add_noise=False, normalise=True, use_sample_pace=True, P_lin=P_lin)


fig, axes = plt.subplots(1, 2, figsize=(12, 5), facecolor='#0a0a0a')

for ax in axes:
    ax.set_facecolor('#151515')
    # Add a visible border around each subplot
    for spine in ax.spines.values():
        spine.set_edgecolor('white')
        spine.set_linewidth(1.0)

# Shared style parameters
clean_color = 'white'
noisy_color = '#4FC3F7'
grid_color = 'gray'

# Axis label style
label_style = dict(color='white', fontsize=16)

# ───────────────────────────────────────────────
# P0
# ───────────────────────────────────────────────
axes[0].plot(k, P0_clean, color=clean_color, label='clean', linewidth=1.6)
axes[0].plot(kL, P0_cleanL, color=clean_color, label='clean', linewidth=1.6)
axes[0].plot(kn, P0_cleann, color=clean_color, label='clean', linewidth=1.6)
axes[0].plot(kL, P0L, color="red", alpha=0.7, label='noisy', linewidth=1.2)
axes[0].plot(k, P0, color=noisy_color, alpha=0.7, label='noisy', linewidth=1.2)
axes[0].set_xscale('log')
axes[0].set_title('Monopole ', color='white', fontsize=13)
axes[0].set_xlabel('k  [h/Mpc]', **label_style)
axes[0].set_ylabel('P₀', **label_style)
axes[0].tick_params(axis='both', colors='white', labelsize=12)

# ───────────────────────────────────────────────
# P2
# ───────────────────────────────────────────────
axes[1].plot(k, P2_clean, color=clean_color, label='clean', linewidth=1.6)
axes[1].plot(k, P2, color=noisy_color, alpha=0.7, label='noisy', linewidth=1.2)
axes[1].set_xscale('log')
axes[1].set_title('Quadrapole ', color='white', fontsize=13)
axes[1].set_xlabel('k  [h/Mpc]', **label_style)
axes[1].set_ylabel('P₂', **label_style)
axes[1].tick_params(axis='both', colors='white', labelsize=12)

"""
# ───────────────────────────────────────────────
# P4
# ───────────────────────────────────────────────
axes[2].plot(k, P4_clean, color=clean_color, label='clean', linewidth=1.6)
axes[2].plot(k, P4, color=noisy_color, alpha=0.7, label='noisy', linewidth=1.2)
axes[2].set_xscale('log')
axes[2].set_title('Hexdecapole ', color='white', fontsize=13)
axes[2].set_xlabel('k  [h/Mpc]', **label_style)
axes[2].set_ylabel('P₄', **label_style)
axes[2].tick_params(axis='both', colors='white', labelsize=12)
"""

plt.tight_layout()
plt.show()
# Out:
# loaded data shape: (500, 4)
# shape after k max: (250,)
# planck data shape: (250, 3)
# loaded data shape: (500, 4)
# shape after k max: (250,)
# planck data shape: (250, 3)
# loaded data shape: (500, 3)
# shape after k max: (250,)
# planck data shape: (250, 3)
# loaded data shape: (500, 3)
# shape after k max: (250,)
# planck data shape: (250, 3)
# loaded data shape: (500, 3)
# shape after k max: (250,)
# planck data shape: (250, 3)
# loaded data shape: (500, 3)
# shape after k max: (250,)
# planck data shape: (250, 3)

# %% [markdown]
# Let's look at the input features as seen by the network.

# %% [markdown]
# ### Classify your spectra and compute confidence
#  (for Bayesian networks only)

# %%
res_fR = get_all_probas(X_fR,
                        model_5,
                        n_classes=5,
                        num_monte_carlo=5,
                        th_prob=0.5,
                        n_samples=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2263/3277369972.py in <cell line: 0>()
# ----> 1 res_fR = get_all_probas(X_fR,
#       2                         model_5,
#       3                         n_classes=5,
#       4                         num_monte_carlo=5,
#       5                         th_prob=0.5,
#
# NameError: name 'get_all_probas' is not defined

# %%
print('P-non-LCDM=%s' %(np.delete(res_fR['P'], [2]).sum()))
plot_hist_1D(res_fR['samples'],
             res_fR['MM'],
             th_prob=0.5,
             P=res_fR['P'],
             inv_labels_dict=inv_labels_dict_5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2263/139502803.py in <cell line: 0>()
# ----> 1 print('P-non-LCDM=%s' %(np.delete(res_fR['P'], [2]).sum()))
#       2 plot_hist_1D(res_fR['samples'],
#       3              res_fR['MM'],
#       4              th_prob=0.5,
#       5              P=res_fR['P'],
#
# NameError: name 'res_fR' is not defined
